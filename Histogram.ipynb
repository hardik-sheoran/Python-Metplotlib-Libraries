# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [26 54 35 56 55 40 28 27 22 28 35 43 39 44 16 21 51 38 29 14 38 55 44 50
#  58 49 41 16 46 33 40 57 53 20 37 48 23 54 25 21 23 20 18 48 56 46 27 11
#  13 54]

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,'auto',(0,100),color = 'y',edgecolor='r')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1)

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,bottom=10)

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,align='mid')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,histtype='step')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,histtype='stepfilled')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,histtype='barstacked')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,orientation='horizontal')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,rwidth = 0.1)

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,log = True)

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'y',edgecolor='r',cumulative=-1,label='Bye')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')
plt.legend()
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'm',edgecolor='r',cumulative=-1,label='Bye')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')

plt.axvline(40,color='g',label = 'axvline')

plt.legend()
plt.show()

# %%
no = [48, 10, 29, 56, 48, 37, 21, 37, 45, 27, 49, 26, 40, 33, 38, 51, 41, 21, 18, 30, 26, 42, 50, 51, 27, 29, 15, 53, 12, 37, 24, 50, 33, 53, 26, 16, 41, 41, 54, 55, 22, 38, 42, 42, 30, 40, 45, 42,
 31, 50]

l = [10,20,30,40,50,60]

plt.hist(no,color = 'm',edgecolor='r',cumulative=-1,label='Bye')

plt.title('Python')
plt.xlabel('Great')
plt.ylabel('No.')

plt.axvline(40,color='g',label = 'axvline')

plt.legend()
plt.grid()
plt.show()
